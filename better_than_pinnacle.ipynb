# %%
import pandas as pd
from bettools import get_data, generate_seasons, calculate_poisson_match_outcomes, calculate_ev_from_odds, kelly_criterion
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.options.mode.chained_assignment = None

# %%
leagues = ['E0']

season_list = generate_seasons(2018, 2019)

df_ls = get_data(season_list, leagues)

main_df = pd.concat(df_ls)

main_df
# Out:
#     Div       Date      HomeTeam        AwayTeam  FTHG  FTAG   PSH   PSD  \
# 0    E0 2018-08-10    Man United       Leicester     2     1  1.58  3.93
# 1    E0 2018-08-11   Bournemouth         Cardiff     2     0  1.89  3.63
# 2    E0 2018-08-11        Fulham  Crystal Palace     0     2  2.50  3.46
# 3    E0 2018-08-11  Huddersfield         Chelsea     0     3  6.41  4.02
# 4    E0 2018-08-11     Newcastle       Tottenham     1     2  3.83  3.57
# ..   ..        ...           ...             ...   ...   ...   ...   ...
# 375  E0 2019-05-12     Liverpool          Wolves     2     0  1.31  5.77
# 376  E0 2019-05-12    Man United         Cardiff     0     2  1.28  6.33
# 377  E0 2019-05-12   Southampton    Huddersfield     1     1  1.44  4.83
# 378  E0 2019-05-12     Tottenham         Everton     2     2  2.10  3.64
# 379  E0 2019-05-12       Watford        West Ham     1     4  2.20  3.85
#
#        PSA  home_max_odds  away_max_odds  draw_max_odds
# 0     7.50           1.58           7.50           4.00
# 1     4.58           1.91           4.75           3.63
# 2     3.00           2.50           3.00           3.46
# 3     1.62           6.50           1.62           4.02
# 4     2.08           3.90           2.10           3.57
# ..     ...            ...            ...            ...
# 375  10.54           1.31          11.50           6.00
# 376  10.21           1.29          11.00           6.50
# 377   7.62           1.44           8.50           4.83
# 378   3.64           2.20           3.70           3.64
# 379   3.21           2.25           3.25           3.85
#
# [380 rows x 12 columns]

# %%
home_bet_df = main_df[main_df['home_max_odds']>main_df['PSH']]

home_bet_df.reset_index(inplace=True, drop=True)

home_bet_df.sort_values('Date',inplace=True)

home_bet_df['profit'] = np.where(home_bet_df['FTHG']>home_bet_df['FTAG'], home_bet_df['home_max_odds']-1, -1)

home_bet_df.reset_index(inplace=True, drop=True)

# %%
# Assuming 'home_bet_df' is your DataFrame and it has a 'profit' column
home_bet_df['profit'].cumsum().plot()

# Customizations
plt.title('Cumulative Profit Over Time')
plt.xlabel('Game Number')
plt.ylabel('Cumulative Profit')
plt.grid(True)

# Show the plot
plt.show()

# %%
leagues = ['E0','E1','E2','E3','SC0','SC1','SC2','D1','D2','I1','I2','SP1','SP2','F1','F2','N1','B1','P1','T1','G1']

season_list = generate_seasons(2016, 2024)

df_ls = get_data(season_list, leagues)

# %%
main_df = pd.concat(df_ls)

# %%
home_bet_df = main_df[main_df['home_max_odds']>main_df['PSH']]

home_bet_df.reset_index(inplace=True, drop=True)

home_bet_df.sort_values('Date',inplace=True)

home_bet_df['profit'] = np.where(home_bet_df['FTHG']>home_bet_df['FTAG'], home_bet_df['home_max_odds']-1, -1)

home_bet_df.reset_index(inplace=True, drop=True)

# %%
home_bet_df['profit'].cumsum().plot()

# Customizations
plt.title('Cumulative Profit Over Time')
plt.xlabel('Game Number')
plt.ylabel('Cumulative Profit')
plt.grid(True)

# Show the plot
plt.show()

# %%
home_bet_df["P_margin"] = (
    1 / home_bet_df["PSH"] + 1 / home_bet_df["PSD"] + 1 / home_bet_df["PSA"]
) - 1

home_bet_df["fair_PSH"] = (3 * home_bet_df["PSH"]) / (
    3 - home_bet_df["P_margin"] * home_bet_df["PSH"]
)
home_bet_df["fair_PSD"] = (3 * home_bet_df["PSD"]) / (
    3 - home_bet_df["P_margin"] * home_bet_df["PSD"]
)
home_bet_df["fair_PSA"] = (3 * home_bet_df["PSA"]) / (
    3 - home_bet_df["P_margin"] * home_bet_df["PSA"]
)

home_bet_df['pinnacle_prob'] = 1/home_bet_df['fair_PSH']

home_bet_df["home_ev"] = home_bet_df.apply(
    lambda x: calculate_ev_from_odds(x["home_max_odds"], x["pinnacle_prob"]), axis=1
)

# %%
bankroll = 100

for i in range(len(home_bet_df)):
    bet_size = kelly_criterion(
        home_bet_df.loc[i]["pinnacle_prob"], home_bet_df.loc[i]["home_max_odds"], bankroll, 0.25
    )
    home_bet_df.loc[i, 'bet_size'] = bet_size
    bankroll = bankroll - bet_size
    if home_bet_df.loc[i]["FTHG"] > home_bet_df.loc[i]["FTAG"]:
        bankroll = bankroll + bet_size * home_bet_df.loc[i]["home_max_odds"]
    home_bet_df.loc[i, "bankroll"] = bankroll

home_bet_df.bankroll.plot()
# Out:
# <Axes: >

# %%
home_bet_df
# Out:
#        Div       Date   HomeTeam          AwayTeam  FTHG  FTAG   PSH   PSD  \
# 0       F2 2016-07-29      Nimes             Laval   0.0   0.0  2.25  3.06
# 1       B1 2016-07-30  Charleroi  Waasland-Beveren   1.0   0.0  1.63  4.08
# 2       B1 2016-07-30   Mouscron        Anderlecht   1.0   2.0  4.07  3.69
# 3       B1 2016-07-31   Kortrijk              Gent   1.0   1.0  3.43  3.46
# 4       B1 2016-07-31   Westerlo          Standard   2.0   2.0  4.70  3.84
# ...    ...        ...        ...               ...   ...   ...   ...   ...
# 23623  SP2 2024-06-02      Eibar            Oviedo   4.0   3.0  1.93  2.97
# 23624  SP2 2024-06-02    Eldense          Sp Gijon   0.0   1.0  5.35  3.97
# 23625  SP2 2024-06-02    Espanol         Cartagena   3.0   0.0  1.40  4.42
# 23626  SP2 2024-06-02    Leganes             Elche   2.0   0.0  1.56  2.97
# 23627  SP2 2024-06-02   Mirandes        Amorebieta   1.0   0.0  2.11  3.51
#
#         PSA  home_max_odds  away_max_odds  draw_max_odds  profit  P_margin  \
# 0      3.93           2.30           3.93           3.20   -1.00  0.025695
# 1      6.08           1.65           6.08           4.08    0.65  0.023069
# 2      1.96           4.20           1.96           3.69   -1.00  0.026907
# 3      2.25           3.50           2.25           3.46   -1.00  0.025007
# 4      1.81           4.75           1.85           3.84   -1.00  0.025669
# ...     ...            ...            ...            ...     ...       ...
# 23623  4.56           1.95           4.56           3.30    0.95  0.074133
# 23624  1.56           5.50           1.57           4.10   -1.00  0.079831
# 23625  7.10           1.46           8.00           4.42    0.46  0.081375
# 23626  9.48           1.57           9.48           3.40    0.57  0.083211
# 23627  3.18           2.15           3.30           3.51    1.15  0.073299
#
#        fair_PSH  fair_PSD   fair_PSA  pinnacle_prob   home_ev  bet_size  \
# 0      2.294212  3.142357   4.066892       0.435880  0.002523  1.008247
# 1      1.650690  4.212149   6.378196       0.605807 -0.000418  1.003601
# 2      4.224200  3.816303   1.995072       0.236731 -0.005729  1.001951
# 3      3.530955  3.562755   2.293006       0.283210 -0.008767  0.998485
# 4      4.896927  3.970454   1.838472       0.204210 -0.030004  0.977920
# ...         ...       ...        ...            ...       ...       ...
# 23623  2.026656  3.205239   5.139086       0.493424 -0.037824  0.969027
# 23624  6.238083  4.438941   1.627563       0.160306 -0.118319  0.892085
# 23625  1.455264  5.022115   8.793526       0.687161  0.003255  1.007873
# 23626  1.630554  3.236631  12.862040       0.613289 -0.037137  0.967936
# 23627  2.224691  3.839255   3.447892       0.449501 -0.033574  0.973868
#
#         bankroll
# 0      98.991753
# 1      99.644094
# 2      98.642143
# 3      97.643659
# 4      96.665739
# ...          ...
# 23623  70.337549
# 23624  69.445464
# 23625  69.909086
# 23626  70.460809
# 23627  71.580758
#
# [23628 rows x 21 columns]

# %%
kelly_criterion(0.435880, 2.3, 100, 1)
# Out:
# 0.19415384615384393
