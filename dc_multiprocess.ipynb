# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import poisson, skellam
from scipy.optimize import minimize
from bettools import (
    get_data,
    generate_seasons,
    calculate_poisson_match_outcomes,
    calculate_ev_from_odds,
)
import statsmodels.api as sm
import statsmodels.formula.api as smf
import warnings
from dixon_coles import (
    rho_correction,
    dc_log_like,
    solve_parameters,
    solve_parameters_decay,
)

# Suppress RuntimeWarnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.options.mode.chained_assignment = None

# %%
def get_1x2_probs(match_score_matrix):
    return dict(
        {
            "H": np.sum(np.tril(match_score_matrix, -1)),
            "A": np.sum(np.triu(match_score_matrix, 1)),
            "D": np.sum(np.diag(match_score_matrix)),
        }
    )


def build_temp_model(dataset, time_diff, xi=0.000, init_params=None):
    test_dataset = dataset[
        (
            (dataset["time_diff"] <= time_diff)
            & (dataset["time_diff"] >= (time_diff - 2))
        )
    ]
    if len(test_dataset) == 0:
        return 0
    train_dataset = dataset[dataset["time_diff"] > time_diff]
    train_dataset["time_diff"] = train_dataset["time_diff"] - time_diff
    params = solve_parameters_decay(train_dataset, xi=xi, init_vals=init_params)
    predictive_score = sum(
        [
            np.log(
                get_1x2_probs(
                    dixon_coles_simulate_match(params, row.HomeTeam, row.AwayTeam)
                )[row.FTR]
            )
            for row in test_dataset.itertuples()
        ]
    )
    return predictive_score


def get_total_score_xi(xi):
    xi_result = [build_temp_model(dc_df, day, xi=xi) for day in range(99, -1, -3)]
    with open("find_xi_1season_{}.txt".format(str(xi)[2:]), "wb") as thefile:
        pickle.dump(xi_result, thefile)


def calc_means(param_dict, homeTeam, awayTeam):
    return [
        np.exp(
            param_dict["attack_" + homeTeam]
            + param_dict["defence_" + awayTeam]
            + param_dict["home_adv"]
        ),
        np.exp(param_dict["defence_" + homeTeam] + param_dict["attack_" + awayTeam]),
    ]


def dixon_coles_simulate_match(params_dict, homeTeam, awayTeam, max_goals=10):
    team_avgs = calc_means(params_dict, homeTeam, awayTeam)
    team_pred = [
        [poisson.pmf(i, team_avg) for i in range(0, max_goals + 1)]
        for team_avg in team_avgs
    ]
    output_matrix = np.outer(np.array(team_pred[0]), np.array(team_pred[1]))
    correction_matrix = np.array(
        [
            [
                rho_correction(
                    home_goals,
                    away_goals,
                    team_avgs[0],
                    team_avgs[1],
                    params_dict["rho"],
                )
                for away_goals in range(2)
            ]
            for home_goals in range(2)
        ]
    )
    output_matrix[:2, :2] = output_matrix[:2, :2] * correction_matrix
    return output_matrix

# %%
def walk_forward_validation(data, initial_train_size, test_size, num_iterations):
    total_rows = len(data)

    train_start = 0
    train_end = initial_train_size
    test_end = train_end + test_size

    results = []
    iteration = 0  # To track the number of iterations
    while test_end <= total_rows and iteration < num_iterations:
        # Splitting the data
        train_data = data.iloc[train_start:train_end]
        test_data = data.iloc[train_end:test_end]

        # Calculating time difference from the end of the training set
        max_train_date = train_data.index.max()
        train_data["time_diff"] = (max_train_date - train_data.index).days

        # Selecting columns (adjust as necessary)
        train_data = train_data[["HomeTeam", "AwayTeam", "FTHG", "FTAG", "time_diff"]]

        successful_fit = False
        attempts = 0
        while (
            not successful_fit and attempts < 5
        ):  # Try fitting parameters up to 5 times
            try:
                params = solve_parameters_decay(train_data, xi=0.00325)
                # Insert your prediction and evaluation logic here, using `params`
                # For each row in test_data, calculate predictions and append to test_data
                test_data = test_data.reset_index()
                for i in range(len(test_data)):
                    home_team = test_data.loc[i]["HomeTeam"]
                    away_team = test_data.loc[i]["AwayTeam"]
                    probs_1x2 = get_1x2_probs(
                        dixon_coles_simulate_match(
                            params, home_team, away_team, max_goals=10
                        )
                    )
                    test_data.loc[i, "home_win_prob"] = probs_1x2["H"]
                    test_data.loc[i, "away_win_prob"] = probs_1x2["A"]
                    test_data.loc[i, "draw_win_prob"] = probs_1x2["D"]
                results.append(test_data)
                successful_fit = True
            except Exception as e:
                # If parameter fitting fails, add more data to the training set and try again
                print(
                    f"Parameter fitting failed on attempt {attempts + 1}: {e}. Trying with a larger training set."
                )
                train_end += test_size  # Expanding the training set window
                if train_end + test_size > total_rows:
                    print(
                        "Not enough data to expand the training set and perform another test. Stopping."
                    )
                    return results
                train_data = data.iloc[train_start:train_end]
                train_data["time_diff"] = (max_train_date - train_data.index).days
                train_data = train_data[
                    ["HomeTeam", "AwayTeam", "FTHG", "FTAG", "time_diff"]
                ]
                attempts += 1
        if successful_fit:
            # Move the window forward
            train_end = test_end
            test_end += test_size
            iteration += 1  # Increment the iteration count
    return results

# %%
from concurrent.futures import ProcessPoolExecutor
from process_chunk import process_chunk
from tqdm import tqdm  # For progress reporting


def walk_forward_validation_parallel(
    data, initial_train_size, test_size, num_iterations
):
    total_rows = len(data)

    # Calculate the start and end indices for each chunk
    indices = [
        (i * test_size, initial_train_size + i * test_size, test_size)
        for i in range(num_iterations)
        if initial_train_size + (i + 1) * test_size <= total_rows
    ]

    with ProcessPoolExecutor(max_workers=7) as executor:
        # Prepare a list of tasks
        tasks = [(data, *idx) for idx in indices]
        # Setup progress bar with total equal to the number of tasks
        progress_bar = tqdm(total=len(tasks), desc="Processing Chunks")

        # Execute tasks and update progress bar as each task completes
        results = []
        for _ in executor.map(process_chunk, tasks):
            progress_bar.update(1)  # Update progress for each completed task
            results.append(_)  # Store result (optional, depending on your needs)

        # Close the progress bar upon completion
        progress_bar.close()

    return results


leagues = [["E0"], ["E1"], ["E2"], ["E3"]]
for league in leagues:
    season_list = generate_seasons(2014, 2024)
    df_ls = get_data(season_list, league)
    main_df = pd.concat(df_ls)
    main_df = main_df.dropna()
    main_df["Date"] = pd.to_datetime(main_df["Date"])
    main_df = main_df.sort_values("Date")
    main_df.set_index("Date", inplace=True)
    res = walk_forward_validation_parallel(
        main_df, 500, 10, int((len(main_df) - 500) / 10)
    )
    results = pd.concat(res)
    results.to_csv(f"results_dc_{league}.csv")
# Out:
# Processing Chunks: 100%|████████████████████████████████| 321/321 [3:08:19<00:00, 35.20s/it]
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 667.6007251543847
#             Iterations: 49
#             Function evaluations: 2461
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 719.3346773587812
#             Iterations: 49
#             Function evaluations: 2465
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 763.3214258595086
#             Iterations: 54
#             Function evaluations: 2719
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 771.6443895772172
#             Iterations: 49
#             Function evaluations: 2468
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 603.2382949079465
#             Iterations: 68
#             Function evaluations: 3808
#             Gradient evaluations: 68
# Parameter fitting failed on attempt 1: 'Cordoba'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Cordoba'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Cordoba'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'Cordoba'. Trying with a larger training set.
# Parameter fitting failed on attempt 5: 'Cordoba'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 682.5976015659281
#             Iterations: 59
#             Function evaluations: 2961
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 686.2297978905864
#             Iterations: 48
#             Function evaluations: 2416
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 749.2594094878515
#             Iterations: 56
#             Function evaluations: 2819
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 777.9472857541804
#             Iterations: 60
#             Function evaluations: 3020
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 624.9236110102033
#             Iterations: 53
#             Function evaluations: 2769
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 674.6311874013145
#             Iterations: 50
#             Function evaluations: 2615
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 704.1842140649926
#             Iterations: 48
#             Function evaluations: 2417
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 715.9130168970821
#             Iterations: 52
#             Function evaluations: 2616
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 757.0173238204783
#             Iterations: 51
#             Function evaluations: 2568
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 773.3866336555138
#             Iterations: 61
#             Function evaluations: 3070
#             Gradient evaluations: 61
# Parameter fitting failed on attempt 1: 'Huesca'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 655.1281431022213
#             Iterations: 67
#             Function evaluations: 3758
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 663.1383083444748
#             Iterations: 50
#             Function evaluations: 2809
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 685.2407388933524
#             Iterations: 66
#             Function evaluations: 3321
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 726.2835559394457
#             Iterations: 51
#             Function evaluations: 2566
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 765.2634028547131
#             Iterations: 46
#             Function evaluations: 2318
#             Gradient evaluations: 46
# Parameter fitting failed on attempt 1: 'Osasuna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 640.8586980536845
#             Iterations: 63
#             Function evaluations: 3542
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 651.8328390560818
#             Iterations: 50
#             Function evaluations: 2805
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 700.6212795559122
#             Iterations: 67
#             Function evaluations: 3372
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 702.7044212458322
#             Iterations: 62
#             Function evaluations: 3116
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 615.8248229332474
#             Iterations: 49
#             Function evaluations: 2459
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 581.1682213995999
#             Iterations: 48
#             Function evaluations: 2503
#             Gradient evaluations: 48
# Parameter fitting failed on attempt 1: 'attack_Elche'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 609.2716167160293
#             Iterations: 66
#             Function evaluations: 3566
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 687.7818082565148
#             Iterations: 52
#             Function evaluations: 2612
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 731.9697821449402
#             Iterations: 55
#             Function evaluations: 2764
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 736.394959295307
#             Iterations: 49
#             Function evaluations: 2466
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 775.8119991394324
#             Iterations: 52
#             Function evaluations: 2616
#             Gradient evaluations: 52
# Parameter fitting failed on attempt 1: 'Vallecano'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 671.8446875674522
#             Iterations: 62
#             Function evaluations: 3234
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 698.8877689008508
#             Iterations: 55
#             Function evaluations: 2873
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 710.7401354023575
#             Iterations: 51
#             Function evaluations: 2563
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 720.1391651923342
#             Iterations: 49
#             Function evaluations: 2462
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 747.9110319741792
#             Iterations: 48
#             Function evaluations: 2416
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 780.8466423808204
#             Iterations: 47
#             Function evaluations: 2370
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 649.3305225031637
#             Iterations: 57
#             Function evaluations: 3089
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 663.812081914473
#             Iterations: 52
#             Function evaluations: 2815
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 625.5375663898078
#             Iterations: 43
#             Function evaluations: 2158
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 659.3330274223549
#             Iterations: 67
#             Function evaluations: 3361
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 681.7671588260076
#             Iterations: 64
#             Function evaluations: 3216
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 623.6507853930145
#             Iterations: 62
#             Function evaluations: 3239
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 689.7764310980134
#             Iterations: 50
#             Function evaluations: 2614
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 703.5140090536613
#             Iterations: 63
#             Function evaluations: 3169
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 727.8178710002778
#             Iterations: 65
#             Function evaluations: 3265
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 674.2396520060464
#             Iterations: 47
#             Function evaluations: 2365
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 710.6782585438764
#             Iterations: 53
#             Function evaluations: 2665
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 765.0051252679976
#             Iterations: 63
#             Function evaluations: 3170
#             Gradient evaluations: 63
# Parameter fitting failed on attempt 1: 'Osasuna'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Osasuna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 655.4123860320358
#             Iterations: 67
#             Function evaluations: 3759
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 650.3851976653781
#             Iterations: 59
#             Function evaluations: 3315
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 704.8275072014696
#             Iterations: 63
#             Function evaluations: 3171
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 721.1333885903634
#             Iterations: 61
#             Function evaluations: 3068
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 752.603569473027
#             Iterations: 52
#             Function evaluations: 2614
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 815.6090126869558
#             Iterations: 49
#             Function evaluations: 2472
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 681.4084621399061
#             Iterations: 51
#             Function evaluations: 2666
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 682.607341612453
#             Iterations: 53
#             Function evaluations: 2774
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 704.6327098317256
#             Iterations: 49
#             Function evaluations: 2466
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 733.7275373595969
#             Iterations: 62
#             Function evaluations: 3120
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 765.9261890742051
#             Iterations: 48
#             Function evaluations: 2414
#             Gradient evaluations: 48
# Parameter fitting failed on attempt 1: 'Valladolid'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Huesca'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 672.7280087127324
#             Iterations: 69
#             Function evaluations: 3867
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 673.7531019315836
#             Iterations: 60
#             Function evaluations: 3370
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 699.6086546703469
#             Iterations: 48
#             Function evaluations: 2410
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 712.793583712885
#             Iterations: 47
#             Function evaluations: 2364
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 725.4079671328628
#             Iterations: 45
#             Function evaluations: 2262
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 785.2886510280503
#             Iterations: 49
#             Function evaluations: 2468
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 623.1903485479471
#             Iterations: 64
#             Function evaluations: 3597
#             Gradient evaluations: 64
# Parameter fitting failed on attempt 1: 'La Coruna'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'La Coruna'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'La Coruna'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'La Coruna'. Trying with a larger training set.
# Parameter fitting failed on attempt 5: 'La Coruna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 696.4422122891069
#             Iterations: 54
#             Function evaluations: 2712
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 681.577633822785
#             Iterations: 70
#             Function evaluations: 3516
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 537.844672655266
#             Iterations: 47
#             Function evaluations: 2354
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 637.0891508962989
#             Iterations: 43
#             Function evaluations: 2158
#             Gradient evaluations: 43
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 598.7900982756755
#             Iterations: 66
#             Function evaluations: 3565
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 626.5363995286154
#             Iterations: 65
#             Function evaluations: 3519
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 707.002825720327
#             Iterations: 58
#             Function evaluations: 2914
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 740.9201083934175
#             Iterations: 56
#             Function evaluations: 2813
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 745.4388113058916
#             Iterations: 50
#             Function evaluations: 2512
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 814.3009480188053
#             Iterations: 53
#             Function evaluations: 2668
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 668.0303727539565
#             Iterations: 53
#             Function evaluations: 2766
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 706.5408112244925
#             Iterations: 58
#             Function evaluations: 2914
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 711.8207568097752
#             Iterations: 61
#             Function evaluations: 3071
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 736.7941983947376
#             Iterations: 50
#             Function evaluations: 2513
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 751.3645181969096
#             Iterations: 50
#             Function evaluations: 2516
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 629.8777335274659
#             Iterations: 61
#             Function evaluations: 3303
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 674.8304580500014
#             Iterations: 70
#             Function evaluations: 3784
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 633.555789074576
#             Iterations: 47
#             Function evaluations: 2362
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 678.911666473095
#             Iterations: 65
#             Function evaluations: 3270
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 728.0982215311593
#             Iterations: 47
#             Function evaluations: 2364
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 638.5204329978883
#             Iterations: 52
#             Function evaluations: 2716
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 700.6789751056814
#             Iterations: 51
#             Function evaluations: 2665
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 698.3479056788012
#             Iterations: 46
#             Function evaluations: 2317
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 715.9936859915672
#             Iterations: 48
#             Function evaluations: 2414
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 752.537484000298
#             Iterations: 64
#             Function evaluations: 3213
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 674.784608798651
#             Iterations: 65
#             Function evaluations: 3266
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 733.9015753051573
#             Iterations: 52
#             Function evaluations: 2616
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 760.505565231215
#             Iterations: 52
#             Function evaluations: 2620
#             Gradient evaluations: 52
# Parameter fitting failed on attempt 1: 'Osasuna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 636.5890728833443
#             Iterations: 67
#             Function evaluations: 3757
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 647.9504951699614
#             Iterations: 52
#             Function evaluations: 2923
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 699.5728434994979
#             Iterations: 63
#             Function evaluations: 3171
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 712.8430680359573
#             Iterations: 63
#             Function evaluations: 3177
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 776.6944895454582
#             Iterations: 52
#             Function evaluations: 2619
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 624.2707503247182
#             Iterations: 60
#             Function evaluations: 3015
#             Gradient evaluations: 60
# Parameter fitting failed on attempt 1: 'attack_Girona'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 651.3487565532773
#             Iterations: 53
#             Function evaluations: 2771
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 695.4712882267481
#             Iterations: 59
#             Function evaluations: 2968
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 726.0448929612107
#             Iterations: 53
#             Function evaluations: 2664
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 757.3266582675012
#             Iterations: 51
#             Function evaluations: 2571
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 780.0595172459809
#             Iterations: 69
#             Function evaluations: 3478
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 649.3987438050054
#             Iterations: 56
#             Function evaluations: 3143
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 672.1121844846656
#             Iterations: 50
#             Function evaluations: 2509
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 692.6283964337504
#             Iterations: 64
#             Function evaluations: 3215
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 721.3630755209513
#             Iterations: 47
#             Function evaluations: 2361
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 751.0901875367083
#             Iterations: 49
#             Function evaluations: 2465
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 607.7228724715511
#             Iterations: 39
#             Function evaluations: 1961
#             Gradient evaluations: 39
# Parameter fitting failed on attempt 1: 'attack_Mallorca'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Osasuna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 660.1456480805589
#             Iterations: 66
#             Function evaluations: 3708
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 690.1271817690007
#             Iterations: 60
#             Function evaluations: 3018
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 690.0887908199128
#             Iterations: 65
#             Function evaluations: 3270
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 568.6209213292542
#             Iterations: 47
#             Function evaluations: 2356
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 658.8209694875846
#             Iterations: 61
#             Function evaluations: 3065
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 613.4111953435864
#             Iterations: 57
#             Function evaluations: 3085
#             Gradient evaluations: 57
# Parameter fitting failed on attempt 1: 'Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 5: 'Vallecano'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 651.6253715186773
#             Iterations: 56
#             Function evaluations: 2812
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 703.2768897462715
#             Iterations: 60
#             Function evaluations: 3013
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 747.6686651606534
#             Iterations: 60
#             Function evaluations: 3017
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 808.0162636365757
#             Iterations: 53
#             Function evaluations: 2669
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 656.6435898994725
#             Iterations: 53
#             Function evaluations: 2766
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 688.4873326056526
#             Iterations: 54
#             Function evaluations: 2819
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 704.5383705823972
#             Iterations: 61
#             Function evaluations: 3069
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 726.077633498001
#             Iterations: 64
#             Function evaluations: 3221
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 753.8292260930504
#             Iterations: 50
#             Function evaluations: 2516
#             Gradient evaluations: 50
# Parameter fitting failed on attempt 1: 'Girona'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 649.8130795744858
#             Iterations: 65
#             Function evaluations: 3520
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 660.3452959734138
#             Iterations: 64
#             Function evaluations: 3466
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 624.58361330021
#             Iterations: 44
#             Function evaluations: 2209
#             Gradient evaluations: 44
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 662.9384250011202
#             Iterations: 66
#             Function evaluations: 3315
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 699.5608137823043
#             Iterations: 51
#             Function evaluations: 2562
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 757.0853324695071
#             Iterations: 50
#             Function evaluations: 2515
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 666.0905006347441
#             Iterations: 70
#             Function evaluations: 3653
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 716.1325370840423
#             Iterations: 65
#             Function evaluations: 3272
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 736.5638497011938
#             Iterations: 61
#             Function evaluations: 3069
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 673.9465385062205
#             Iterations: 61
#             Function evaluations: 3063
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 729.2393722357397
#             Iterations: 53
#             Function evaluations: 2666
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 758.8679721076502
#             Iterations: 50
#             Function evaluations: 2515
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 794.5111779521952
#             Iterations: 49
#             Function evaluations: 2471
#             Gradient evaluations: 49
# Parameter fitting failed on attempt 1: 'defence_Osasuna'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Osasuna'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Osasuna'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 908.7300503074213
#             Iterations: 67
#             Function evaluations: 3773
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 691.6764342402831
#             Iterations: 62
#             Function evaluations: 3117
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 696.5741628244564
#             Iterations: 62
#             Function evaluations: 3117
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 756.3069431263111
#             Iterations: 59
#             Function evaluations: 2969
#             Gradient evaluations: 59
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 803.4923214273693
#             Iterations: 53
#             Function evaluations: 2672
#             Gradient evaluations: 53
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 648.414440924505
#             Iterations: 48
#             Function evaluations: 2508
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 689.147693941463
#             Iterations: 52
#             Function evaluations: 2719
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 713.4688249295307
#             Iterations: 54
#             Function evaluations: 2716
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 728.1655698299879
#             Iterations: 56
#             Function evaluations: 2816
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 748.9747326013893
#             Iterations: 54
#             Function evaluations: 2718
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 799.9998460197476
#             Iterations: 55
#             Function evaluations: 2772
#             Gradient evaluations: 55
# Parameter fitting failed on attempt 1: 'defence_Valladolid'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Valladolid'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Valladolid'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'Huesca'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 939.2467060789392
#             Iterations: 70
#             Function evaluations: 3937
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 686.6633713216889
#             Iterations: 47
#             Function evaluations: 2360
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 699.2550517589011
#             Iterations: 47
#             Function evaluations: 2363
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 735.0014646069138
#             Iterations: 47
#             Function evaluations: 2361
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 778.9716399115
#             Iterations: 47
#             Function evaluations: 2368
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 621.8841970642385
#             Iterations: 50
#             Function evaluations: 2813
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 661.4661970985741
#             Iterations: 49
#             Function evaluations: 2749
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 695.7581858931279
#             Iterations: 65
#             Function evaluations: 3271
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 696.2809009927081
#             Iterations: 48
#             Function evaluations: 2416
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 550.6639395184438
#             Iterations: 47
#             Function evaluations: 2358
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 650.5015505103681
#             Iterations: 54
#             Function evaluations: 2712
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 603.1873388450052
#             Iterations: 62
#             Function evaluations: 3354
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 636.4262270968276
#             Iterations: 50
#             Function evaluations: 2709
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 694.787589201384
#             Iterations: 63
#             Function evaluations: 3165
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 741.9420577170413
#             Iterations: 61
#             Function evaluations: 3070
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 758.9120588861745
#             Iterations: 47
#             Function evaluations: 2367
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 633.5368006011247
#             Iterations: 46
#             Function evaluations: 2309
#             Gradient evaluations: 46
# Parameter fitting failed on attempt 1: 'defence_Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Vallecano'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Vallecano'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 714.7679023455559
#             Iterations: 61
#             Function evaluations: 3185
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 699.162903375843
#             Iterations: 58
#             Function evaluations: 2920
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 706.0387492801402
#             Iterations: 60
#             Function evaluations: 3015
#             Gradient evaluations: 60
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 742.1603877609847
#             Iterations: 49
#             Function evaluations: 2462
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 760.4848714312305
#             Iterations: 64
#             Function evaluations: 3220
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 656.2848369600244
#             Iterations: 64
#             Function evaluations: 3468
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 702.6537046221616
#             Iterations: 49
#             Function evaluations: 2465
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 629.2421595821208
#             Iterations: 47
#             Function evaluations: 2359
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 673.8609392833137
#             Iterations: 66
#             Function evaluations: 3313
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 732.7865766574199
#             Iterations: 47
#             Function evaluations: 2364
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 628.0977381942108
#             Iterations: 52
#             Function evaluations: 2714
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 692.2359154229086
#             Iterations: 48
#             Function evaluations: 2510
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 697.7484030100954
#             Iterations: 62
#             Function evaluations: 3118
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 724.2109574457972
#             Iterations: 46
#             Function evaluations: 2314
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 757.2187976238342
#             Iterations: 63
#             Function evaluations: 3164
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 687.1570528836246
#             Iterations: 46
#             Function evaluations: 2312
#             Gradient evaluations: 46
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 698.4125583977265
#             Iterations: 50
#             Function evaluations: 2514
#             Gradient evaluations: 50
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 747.7191121035592
#             Iterations: 66
#             Function evaluations: 3325
#             Gradient evaluations: 66
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 788.6519561744244
#             Iterations: 49
#             Function evaluations: 2471
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 643.7338679522735
#             Iterations: 52
#             Function evaluations: 2922
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 686.2423311644834
#             Iterations: 57
#             Function evaluations: 3208
#             Gradient evaluations: 57
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 693.039498927175
#             Iterations: 55
#             Function evaluations: 2766
#             Gradient evaluations: 55
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 754.590909676841
#             Iterations: 48
#             Function evaluations: 2416
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 786.0422392908807
#             Iterations: 51
#             Function evaluations: 2568
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 631.0071421359869
#             Iterations: 61
#             Function evaluations: 3187
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 684.2279318460127
#             Iterations: 52
#             Function evaluations: 2719
#             Gradient evaluations: 52
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 706.681621146122
#             Iterations: 62
#             Function evaluations: 3119
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 725.0672030636504
#             Iterations: 61
#             Function evaluations: 3067
#             Gradient evaluations: 61
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 744.7098277043078
#             Iterations: 51
#             Function evaluations: 2569
#             Gradient evaluations: 51
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 790.4927201244825
#             Iterations: 47
#             Function evaluations: 2370
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 629.7027215911088
#             Iterations: 54
#             Function evaluations: 3034
#             Gradient evaluations: 54
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 664.6793500857755
#             Iterations: 65
#             Function evaluations: 3656
#             Gradient evaluations: 65
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 694.1738123974384
#             Iterations: 47
#             Function evaluations: 2360
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 724.5827230464063
#             Iterations: 49
#             Function evaluations: 2461
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 755.2708728949283
#             Iterations: 58
#             Function evaluations: 2916
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 615.5415667120951
#             Iterations: 64
#             Function evaluations: 3594
#             Gradient evaluations: 64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 657.249917363584
#             Iterations: 49
#             Function evaluations: 2753
#             Gradient evaluations: 49
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 702.4435323529216
#             Iterations: 47
#             Function evaluations: 2366
#             Gradient evaluations: 47
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 692.7498636062446
#             Iterations: 58
#             Function evaluations: 2915
#             Gradient evaluations: 58
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 583.7734202747456
#             Iterations: 48
#             Function evaluations: 2407
#             Gradient evaluations: 48
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 676.3314663523512
#             Iterations: 56
#             Function evaluations: 2816
#             Gradient evaluations: 56
# Parameter fitting failed on attempt 1: 'attack_Cadiz'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 703.4852053309855
#             Iterations: 67
#             Function evaluations: 3493
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 663.224423126813
#             Iterations: 57
#             Function evaluations: 2860
#             Gradient evaluations: 57
# ...
#             Gradient evaluations: 93
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 752.0652521507752
#             Iterations: 84
#             Function evaluations: 5229
#             Gradient evaluations: 84
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 752.1255063879584
#             Iterations: 77
#             Function evaluations: 4782
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 766.5671798525248
#             Iterations: 75
#             Function evaluations: 4658
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 799.7595291119435
#             Iterations: 72
#             Function evaluations: 4481
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 833.764390934301
#             Iterations: 71
#             Function evaluations: 4419
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 683.0687993010522
#             Iterations: 75
#             Function evaluations: 4655
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 720.4252573942342
#             Iterations: 88
#             Function evaluations: 5467
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 755.6773512166556
#             Iterations: 77
#             Function evaluations: 4783
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 725.1185633243459
#             Iterations: 78
#             Function evaluations: 4847
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 749.022728449322
#             Iterations: 75
#             Function evaluations: 4659
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 763.316413844124
#             Iterations: 57
#             Function evaluations: 3549
#             Gradient evaluations: 57
# Parameter fitting failed on attempt 1: 'Fuenlabrada'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Fuenlabrada'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Fuenlabrada'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'Fuenlabrada'. Trying with a larger training set.
# Parameter fitting failed on attempt 5: 'Fuenlabrada'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 634.3259108373367
#             Iterations: 70
#             Function evaluations: 4345
#             Gradient evaluations: 70
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 653.7921232736749
#             Iterations: 92
#             Function evaluations: 5721
#             Gradient evaluations: 92
# Iteration limit reached    (Exit mode 9)
#             Current function value: 713.6969088258903
#             Iterations: 100
#             Function evaluations: 6265
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 729.748933009724
#             Iterations: 76
#             Function evaluations: 4720
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 741.078072833282
#             Iterations: 75
#             Function evaluations: 4655
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 740.8278602661757
#             Iterations: 74
#             Function evaluations: 4593
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 739.5462558569192
#             Iterations: 78
#             Function evaluations: 4849
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 727.3170327442994
#             Iterations: 81
#             Function evaluations: 5030
#             Gradient evaluations: 81
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 754.9237446035928
#             Iterations: 75
#             Function evaluations: 4657
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 784.2596091494785
#             Iterations: 75
#             Function evaluations: 4668
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 795.6205986932714
#             Iterations: 72
#             Function evaluations: 4481
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 683.628822149264
#             Iterations: 74
#             Function evaluations: 4599
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 710.7876350929973
#             Iterations: 76
#             Function evaluations: 4716
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 741.3229082813855
#             Iterations: 88
#             Function evaluations: 5468
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 737.9688709026482
#             Iterations: 74
#             Function evaluations: 4595
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 746.7204999998894
#             Iterations: 72
#             Function evaluations: 4470
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 777.2570949249949
#             Iterations: 72
#             Function evaluations: 4475
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 776.4998453470259
#             Iterations: 68
#             Function evaluations: 4237
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 685.7409216889162
#             Iterations: 75
#             Function evaluations: 4661
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 717.8358036860095
#             Iterations: 88
#             Function evaluations: 5472
#             Gradient evaluations: 88
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 755.7460787160456
#             Iterations: 76
#             Function evaluations: 4720
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 750.0928852442477
#             Iterations: 76
#             Function evaluations: 4718
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 769.5363963128328
#             Iterations: 73
#             Function evaluations: 4535
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 794.1881034797469
#             Iterations: 62
#             Function evaluations: 3861
#             Gradient evaluations: 62
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 662.4991306957453
#             Iterations: 75
#             Function evaluations: 4659
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 695.2341603559865
#             Iterations: 76
#             Function evaluations: 4720
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 715.4714858355204
#             Iterations: 96
#             Function evaluations: 5984
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 725.5284461067511
#             Iterations: 72
#             Function evaluations: 4471
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 735.3234362253592
#             Iterations: 74
#             Function evaluations: 4597
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 771.2062355156377
#             Iterations: 69
#             Function evaluations: 4290
#             Gradient evaluations: 69
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 648.3170961823649
#             Iterations: 63
#             Function evaluations: 4540
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 705.6654296822179
#             Iterations: 72
#             Function evaluations: 4471
#             Gradient evaluations: 72
# Iteration limit reached    (Exit mode 9)
#             Current function value: 756.9021384872611
#             Iterations: 100
#             Function evaluations: 6254
#             Gradient evaluations: 100
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 764.5230914037774
#             Iterations: 71
#             Function evaluations: 4408
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 776.1952450494547
#             Iterations: 72
#             Function evaluations: 4329
#             Gradient evaluations: 72
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 650.3463559106536
#             Iterations: 71
#             Function evaluations: 4265
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 740.8204090577304
#             Iterations: 66
#             Function evaluations: 3986
#             Gradient evaluations: 66
# Parameter fitting failed on attempt 1: 'defence_Logrones'. Trying with a larger training set.
# Parameter fitting failed on attempt 2: 'Logrones'. Trying with a larger training set.
# Parameter fitting failed on attempt 3: 'Logrones'. Trying with a larger training set.
# Parameter fitting failed on attempt 4: 'Sabadell'. Trying with a larger training set.
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 856.7979575403201
#             Iterations: 77
#             Function evaluations: 5555
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 735.4619512807975
#             Iterations: 79
#             Function evaluations: 4913
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 753.2369958265209
#             Iterations: 77
#             Function evaluations: 4780
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 749.8400859346235
#             Iterations: 73
#             Function evaluations: 4531
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 797.4127891074276
#             Iterations: 73
#             Function evaluations: 4536
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 796.9540513223877
#             Iterations: 67
#             Function evaluations: 4168
#             Gradient evaluations: 67
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 667.8908461130517
#             Iterations: 71
#             Function evaluations: 4411
#             Gradient evaluations: 71
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 687.1079333639229
#             Iterations: 78
#             Function evaluations: 4847
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 750.9286855315752
#             Iterations: 78
#             Function evaluations: 4844
#             Gradient evaluations: 78
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 739.5731461549258
#             Iterations: 79
#             Function evaluations: 4904
#             Gradient evaluations: 79
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 757.9772319135351
#             Iterations: 73
#             Function evaluations: 4537
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 792.8489110112564
#             Iterations: 75
#             Function evaluations: 4662
#             Gradient evaluations: 75
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 805.0062778942117
#             Iterations: 68
#             Function evaluations: 4237
#             Gradient evaluations: 68
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 685.9165213706799
#             Iterations: 96
#             Function evaluations: 5993
#             Gradient evaluations: 96
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 729.1337095284514
#             Iterations: 73
#             Function evaluations: 4535
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 731.6931096878276
#             Iterations: 90
#             Function evaluations: 5591
#             Gradient evaluations: 90
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 723.0166725757819
#             Iterations: 76
#             Function evaluations: 4723
#             Gradient evaluations: 76
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 741.6654961801925
#             Iterations: 74
#             Function evaluations: 4593
#             Gradient evaluations: 74
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 750.8852975248643
#             Iterations: 83
#             Function evaluations: 5160
#             Gradient evaluations: 83
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 644.4591689937919
#             Iterations: 73
#             Function evaluations: 4533
#             Gradient evaluations: 73
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 700.2221607052618
#             Iterations: 97
#             Function evaluations: 6046
#             Gradient evaluations: 97
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 727.6884671366879
#             Iterations: 77
#             Function evaluations: 4783
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 735.362760944124
#             Iterations: 77
#             Function evaluations: 4788
#             Gradient evaluations: 77
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 748.257822831701
#             Iterations: 73
#             Function evaluations: 4538
#             Gradient evaluations: 73
